# %% [markdown]
# # Levy_distribution_Histograma_+_Curve
#
# **Name:** -- Ortiz Porras Juan Pablo --
#
# **e-mail:** -- juan.ortiz4968@alumnos.udg.mx --

# %% [markdown]
# # Modules

# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy.stats import levy_stable

# %% [markdown]
# # Variables

# %%
n_samples = 150  
samples = levy_stable.rvs(alpha, beta, loc=m, scale=scale, size=n_samples)

# %% [markdown]
# # Curve Generator

# %%
x = np.linspace(np.min(samples), np.max(samples), 1000)
pdf_curve = levy_stable.pdf(x, alpha, beta, loc=m, scale=scale)

# %% [markdown]
# # Plot

# %%
plt.figure(figsize=(10, 6))
plt.hist(samples, bins=50, density=True, alpha=0.6, color='g', label='Histograma')
plt.plot(x, pdf_curve, 'r', lw=2, label=f'Curva PDF (alpha={alpha}, beta={beta})')

plt.title('Lévy distribution - Histograma + Curve')
plt.xlabel('Value')
plt.ylabel('probability')
plt.legend()
plt.grid(True)
plt.show()
